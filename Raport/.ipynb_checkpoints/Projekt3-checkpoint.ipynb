# %% [markdown]
# # PROJEKT3 - ANALIZA SYGNALOW
# Patryk Jakiel 197733
# Szymon Wójcik 198212
#
# Funkcjonalnosci podstawowe (z DFT oraz iDFT) oraz usuwanie wysokich częstotliwości korzystając z DFT
#
# Wykorzystane biblioteki:
#
#     - matplotplusplus (c++)
#
#     - audioFile (c++)
#
#     - pybind11
#
# oraz pozostałe biblioteki w c++ (iostream, vector, cmath, complex, algorithm)

# %% [markdown]
# # Wizualizacja sygnałów z wykorzystaniem biblioteki matplotplusplus
#
# Przykład pokazujący wizualizowanie sygnału z pliku audio zadanego w plikach

# %%
import sys, os
sys.path.append("../build")

from Debug import Signal

Signal.wizualizacja_sygnalu()

# %% [markdown]
# ![wizualizacja sygnalu z audio.png](attachment:3d974275-6d6d-4bc2-8659-08341e473192.png)

# %% [markdown]
# # DFT oraz transformata odwrotna
#
# Dft oraz transformata odwrotna dla zadanego sygnalu (w tym przypadku sinus, czas trwania 1, czestotliwosc 20, amplituda 50)

# %%
import sys, os
sys.path.append("../build")

from Debug import Signal

Signal.DFT_iDFT(1, 1, 20, 50)

# %% [markdown]
# ![dft sinus.png](attachment:beda7f8f-9f71-4f46-a6cb-22761d8b76a4.png)

# %% [markdown]
# ![idft sinus.png](attachment:da9438e7-8f0d-49c0-b81e-bd190d6f9c3b.png)

# %% [markdown]
# # Generowanie sygnalow o zadanym ksztalcie, czestotliwosci, amplitudzie oraz czasie trwania
#
# Wybor ksztaltu (1 parametr podawany do funkcji 1 - sin, 2 - cos, 3 - prostokatny, 4 - piloksztaltny, 5 - trojkatny)
#
# Ponizej 4 przykladowe sygnaly:
#
#     - sin (czas trwania 4, czestotliwosc 2, amplituda 10)
#     - cos (czas trwania 5, czestotliwosc 5, amplituda 5)
#     - prostokatny (czas trwania 1, czestotliwosc 20, amplituda 50)
#     - trojkatny (czas trwania 2, czestotliwosc 10, amplituda 100)

# %%
import sys, os
sys.path.append("../build")

from Debug import Signal

Signal.generowanie_sygnalu(1, 4, 2, 10)

# %% [markdown]
# ![wygenerowany sinus.png](attachment:c5a1c631-5c92-4a34-85d1-e18183893fb2.png)

# %%
import sys, os
sys.path.append("../build")

from Debug import Signal

Signal.generowanie_sygnalu(2, 5, 5, 5)

# %% [markdown]
# ![wygenerowany cos.png](attachment:5a20ac53-e98d-40be-9f04-f8cbbb7ea82f.png)

# %%
import sys, os
sys.path.append("../build")

from Debug import Signal

Signal.generowanie_sygnalu(3, 1, 20, 50)

# %% [markdown]
# ![wygenerowany prostokatny.png](attachment:967eb117-4b2b-403c-9004-43add44e9155.png)

# %%
import sys, os
sys.path.append("../build")

from Debug import Signal

Signal.generowanie_sygnalu(5, 2, 10, 100)

# %% [markdown]
# ![wygenerowany trojkatny.png](attachment:b3379c5a-a0b3-482e-9de7-6fe0f4c924a6.png)

# %% [markdown]
# # Usuwanie wysokich czestotliwosci z sygnalu (przy uzyciu dft)
#
# Ponizej przedstawione 2 sygnaly, pierwszy sygnal oryginalny (z audio), drugi po odfiltrowaniu czestotliwosci wysokich przy wyborze czestotliwosci odciecia 5.

# %%
import sys, os
sys.path.append("../build")

from Debug import Signal

Signal.usuwanie_czestotliwosci(5)

# %% [markdown]
# ![oryginalny sygnal przed obcieciem.png](attachment:75630e21-2add-4eb2-9c2a-bc89a8fcf695.png)

# %% [markdown]
# ![sygnal po filtracji (wysokich czestotliwosci).png](attachment:3eefc14e-6135-454e-bee6-251188c1b1a6.png)
